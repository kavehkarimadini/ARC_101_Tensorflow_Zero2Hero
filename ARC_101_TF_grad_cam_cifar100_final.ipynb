# %% [markdown]
# # Grad-CAM class activation visualization
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2020/04/26<br>
# **Last modified:** 2021/03/07<br>
# **Description:** How to obtain a class activation heatmap for an image classification model.

# %% [markdown]
# Adapted from Deep Learning with Python (2017).
#
# ## Setup

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, Flatten, Dropout
from keras.models import Model
from keras.optimizers import Adam
# Display
from IPython.display import Image, display
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Configurable parameters
#
# You can change these to another model.
#
# To get the values for `last_conv_layer_name` use `model.summary()`
# to see the names of all layers in the model.

# %%
preprocess_input = keras.applications.efficientnet_v2.preprocess_input
decode_predictions = keras.applications.efficientnet_v2.decode_predictions

# %%
model_builder = keras.applications.EfficientNetV2B0
img_size = (32, 32)
# The local path to our target image
# img_path = keras.utils.get_file(
#     "cow.jpg", "/content/cow.jpg"
# )

# display(Image("/content/cow.jpg"))

# %% [markdown]
# ## The Grad-CAM algorithm

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.utils.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.utils.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array

# %%
def generate_heatmap_efficientnet_v2(img_array,model , last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = keras.models.Model(
        model.inputs, [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Preprocess the input image for EfficientNetV2
    img_array = preprocess_input(img_array)

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    heatmap = last_conv_layer_output[0] @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)

    return heatmap.numpy()

# %% [markdown]
# ## Let's test-drive it

# %%
# Prepare image
img_array = preprocess_input(get_img_array("/content/Best-Horses-Quarter-Horse.jpg", size=img_size))

# %%
# Make model
model = model_builder(weights="imagenet",input_shape=(32, 32, 3),include_top=False)

# %%
# Make model
# model = model_builder(weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0.h5
# 29403144/29403144 [==============================] - 1s 0us/step

# %%
model.trainable = False

# %%
# Define the last layer for classification
last_layer = model.output
last_layer = GlobalAveragePooling2D()(last_layer)
last_layer = Flatten()(last_layer)
last_layer = Dense(1024, activation='relu')(last_layer)
last_layer = Dense(1024, activation='relu')(last_layer)
last_layer = Dropout(0.5)(last_layer)
last_layer = Dense(1024, activation='relu')(last_layer)
last_layer = Dense(1024, activation='relu')(last_layer)
predictions = Dense(100, activation='softmax')(last_layer)

# %%
# Create the modified model
model = Model(inputs=model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  rescaling_2 (Rescaling)     (None, 32, 32, 3)            0         ['input_3[0][0]']
#
#  normalization_2 (Normaliza  (None, 32, 32, 3)            0         ['rescaling_2[0][0]']
#  tion)
#
#  stem_conv (Conv2D)          (None, 16, 16, 32)           864       ['normalization_2[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 16, 16, 32)           128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 16, 16, 32)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 16, 16, 16)           4608      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 16, 16, 16)           64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 16, 16, 16)           0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block2a_expand_conv (Conv2  (None, 8, 8, 64)             9216      ['block1a_project_activation[0
#  D)                                                                 ][0]']
#
#  block2a_expand_bn (BatchNo  (None, 8, 8, 64)             256       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 8, 8, 64)             0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 8, 8, 32)             2048      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 8, 8, 32)             128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 8, 8, 128)            36864     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 8, 8, 128)            512       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 8, 8, 128)            0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 8, 8, 32)             4096      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 8, 8, 32)             128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 8, 8, 32)             0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 8, 8, 32)             0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 4, 4, 128)            36864     ['block2b_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 4, 4, 128)            512       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 4, 4, 128)            0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 4, 4, 48)             6144      ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 4, 4, 48)             192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 4, 4, 192)            82944     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 4, 4, 192)            768       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 4, 4, 192)            0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 4, 4, 48)             9216      ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 4, 4, 48)             192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 4, 4, 48)             0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 4, 4, 48)             0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 4, 4, 192)            9216      ['block3b_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 4, 4, 192)            768       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 4, 4, 192)            0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 2, 2, 192)            1728      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 2, 2, 192)            768       ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 2, 2, 192)            0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 192)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             2316      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 192)            2496      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 2, 2, 192)            0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 2, 2, 96)             18432     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 2, 2, 96)             384       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 2, 2, 384)            36864     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 2, 2, 384)            1536      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 2, 2, 384)            0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 2, 2, 384)            3456      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 2, 2, 384)            1536      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 2, 2, 384)            0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 384)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 2, 2, 384)            0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 2, 2, 96)             36864     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 2, 2, 96)             384       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 2, 2, 96)             0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 2, 2, 96)             0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 2, 2, 384)            36864     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 2, 2, 384)            1536      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 2, 2, 384)            0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 2, 2, 384)            3456      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 2, 2, 384)            1536      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 2, 2, 384)            0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 384)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 2, 2, 384)            0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 2, 2, 96)             36864     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 2, 2, 96)             384       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 2, 2, 96)             0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 2, 2, 96)             0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 2, 2, 576)            55296     ['block4c_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 2, 2, 576)            2304      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 2, 2, 576)            0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 2, 2, 576)            5184      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 2, 2, 576)            2304      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 2, 2, 576)            0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 576)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 2, 2, 576)            0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 2, 2, 112)            64512     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 2, 2, 112)            448       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 2, 2, 672)            75264     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 2, 2, 672)            2688      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 2, 2, 672)            0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv2 (Depthwise  (None, 2, 2, 672)            6048      ['block5b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5b_bn (BatchNormaliza  (None, 2, 2, 672)            2688      ['block5b_dwconv2[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 2, 2, 672)            0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 672)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 2, 2, 672)            0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 2, 2, 112)            75264     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 2, 2, 112)            448       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 2, 2, 112)            0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 2, 2, 112)            0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 2, 2, 672)            75264     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 2, 2, 672)            2688      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 2, 2, 672)            0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv2 (Depthwise  (None, 2, 2, 672)            6048      ['block5c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5c_bn (BatchNormaliza  (None, 2, 2, 672)            2688      ['block5c_dwconv2[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 2, 2, 672)            0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 672)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 2, 2, 672)            0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 2, 2, 112)            75264     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 2, 2, 112)            448       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 2, 2, 112)            0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 2, 2, 112)            0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2  (None, 2, 2, 672)            75264     ['block5c_add[0][0]']
#  D)
#
#  block5d_expand_bn (BatchNo  (None, 2, 2, 672)            2688      ['block5d_expand_conv[0][0]']
#  rmalization)
#
#  block5d_expand_activation   (None, 2, 2, 672)            0         ['block5d_expand_bn[0][0]']
#  (Activation)
#
#  block5d_dwconv2 (Depthwise  (None, 2, 2, 672)            6048      ['block5d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5d_bn (BatchNormaliza  (None, 2, 2, 672)            2688      ['block5d_dwconv2[0][0]']
#  tion)
#
#  block5d_activation (Activa  (None, 2, 2, 672)            0         ['block5d_bn[0][0]']
#  tion)
#
#  block5d_se_squeeze (Global  (None, 672)                  0         ['block5d_activation[0][0]']
#  AveragePooling2D)
#
#  block5d_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5d_se_squeeze[0][0]']
#  e)
#
#  block5d_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5d_se_reshape[0][0]']
#
#  block5d_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5d_se_reduce[0][0]']
#
#  block5d_se_excite (Multipl  (None, 2, 2, 672)            0         ['block5d_activation[0][0]',
#  y)                                                                  'block5d_se_expand[0][0]']
#
#  block5d_project_conv (Conv  (None, 2, 2, 112)            75264     ['block5d_se_excite[0][0]']
#  2D)
#
#  block5d_project_bn (BatchN  (None, 2, 2, 112)            448       ['block5d_project_conv[0][0]']
#  ormalization)
#
#  block5d_drop (Dropout)      (None, 2, 2, 112)            0         ['block5d_project_bn[0][0]']
#
#  block5d_add (Add)           (None, 2, 2, 112)            0         ['block5d_drop[0][0]',
#                                                                      'block5c_add[0][0]']
#
#  block5e_expand_conv (Conv2  (None, 2, 2, 672)            75264     ['block5d_add[0][0]']
#  D)
#
#  block5e_expand_bn (BatchNo  (None, 2, 2, 672)            2688      ['block5e_expand_conv[0][0]']
#  rmalization)
#
#  block5e_expand_activation   (None, 2, 2, 672)            0         ['block5e_expand_bn[0][0]']
#  (Activation)
#
#  block5e_dwconv2 (Depthwise  (None, 2, 2, 672)            6048      ['block5e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5e_bn (BatchNormaliza  (None, 2, 2, 672)            2688      ['block5e_dwconv2[0][0]']
#  tion)
#
#  block5e_activation (Activa  (None, 2, 2, 672)            0         ['block5e_bn[0][0]']
#  tion)
#
#  block5e_se_squeeze (Global  (None, 672)                  0         ['block5e_activation[0][0]']
#  AveragePooling2D)
#
#  block5e_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5e_se_squeeze[0][0]']
#  e)
#
#  block5e_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5e_se_reshape[0][0]']
#
#  block5e_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5e_se_reduce[0][0]']
#
#  block5e_se_excite (Multipl  (None, 2, 2, 672)            0         ['block5e_activation[0][0]',
#  y)                                                                  'block5e_se_expand[0][0]']
#
#  block5e_project_conv (Conv  (None, 2, 2, 112)            75264     ['block5e_se_excite[0][0]']
#  2D)
#
#  block5e_project_bn (BatchN  (None, 2, 2, 112)            448       ['block5e_project_conv[0][0]']
#  ormalization)
#
#  block5e_drop (Dropout)      (None, 2, 2, 112)            0         ['block5e_project_bn[0][0]']
#
#  block5e_add (Add)           (None, 2, 2, 112)            0         ['block5e_drop[0][0]',
#                                                                      'block5d_add[0][0]']
#
#  block6a_expand_conv (Conv2  (None, 2, 2, 672)            75264     ['block5e_add[0][0]']
#  D)
#
#  block6a_expand_bn (BatchNo  (None, 2, 2, 672)            2688      ['block6a_expand_conv[0][0]']
#  rmalization)
#
#  block6a_expand_activation   (None, 2, 2, 672)            0         ['block6a_expand_bn[0][0]']
#  (Activation)
#
#  block6a_dwconv2 (Depthwise  (None, 1, 1, 672)            6048      ['block6a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6a_bn (BatchNormaliza  (None, 1, 1, 672)            2688      ['block6a_dwconv2[0][0]']
#  tion)
#
#  block6a_activation (Activa  (None, 1, 1, 672)            0         ['block6a_bn[0][0]']
#  tion)
#
#  block6a_se_squeeze (Global  (None, 672)                  0         ['block6a_activation[0][0]']
#  AveragePooling2D)
#
#  block6a_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block6a_se_squeeze[0][0]']
#  e)
#
#  block6a_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multipl  (None, 1, 1, 672)            0         ['block6a_activation[0][0]',
#  y)                                                                  'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv  (None, 1, 1, 192)            129024    ['block6a_se_excite[0][0]']
#  2D)
#
#  block6a_project_bn (BatchN  (None, 1, 1, 192)            768       ['block6a_project_conv[0][0]']
#  ormalization)
#
#  block6b_expand_conv (Conv2  (None, 1, 1, 1152)           221184    ['block6a_project_bn[0][0]']
#  D)
#
#  block6b_expand_bn (BatchNo  (None, 1, 1, 1152)           4608      ['block6b_expand_conv[0][0]']
#  rmalization)
#
#  block6b_expand_activation   (None, 1, 1, 1152)           0         ['block6b_expand_bn[0][0]']
#  (Activation)
#
#  block6b_dwconv2 (Depthwise  (None, 1, 1, 1152)           10368     ['block6b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6b_bn (BatchNormaliza  (None, 1, 1, 1152)           4608      ['block6b_dwconv2[0][0]']
#  tion)
#
#  block6b_activation (Activa  (None, 1, 1, 1152)           0         ['block6b_bn[0][0]']
#  tion)
#
#  block6b_se_squeeze (Global  (None, 1152)                 0         ['block6b_activation[0][0]']
#  AveragePooling2D)
#
#  block6b_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6b_se_squeeze[0][0]']
#  e)
#
# ...
#
#  block6e_drop (Dropout)      (None, 1, 1, 192)            0         ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)           (None, 1, 1, 192)            0         ['block6e_drop[0][0]',
#                                                                      'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2  (None, 1, 1, 1152)           221184    ['block6e_add[0][0]']
#  D)
#
#  block6f_expand_bn (BatchNo  (None, 1, 1, 1152)           4608      ['block6f_expand_conv[0][0]']
#  rmalization)
#
#  block6f_expand_activation   (None, 1, 1, 1152)           0         ['block6f_expand_bn[0][0]']
#  (Activation)
#
#  block6f_dwconv2 (Depthwise  (None, 1, 1, 1152)           10368     ['block6f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6f_bn (BatchNormaliza  (None, 1, 1, 1152)           4608      ['block6f_dwconv2[0][0]']
#  tion)
#
#  block6f_activation (Activa  (None, 1, 1, 1152)           0         ['block6f_bn[0][0]']
#  tion)
#
#  block6f_se_squeeze (Global  (None, 1152)                 0         ['block6f_activation[0][0]']
#  AveragePooling2D)
#
#  block6f_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6f_se_squeeze[0][0]']
#  e)
#
#  block6f_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multipl  (None, 1, 1, 1152)           0         ['block6f_activation[0][0]',
#  y)                                                                  'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv  (None, 1, 1, 192)            221184    ['block6f_se_excite[0][0]']
#  2D)
#
#  block6f_project_bn (BatchN  (None, 1, 1, 192)            768       ['block6f_project_conv[0][0]']
#  ormalization)
#
#  block6f_drop (Dropout)      (None, 1, 1, 192)            0         ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)           (None, 1, 1, 192)            0         ['block6f_drop[0][0]',
#                                                                      'block6e_add[0][0]']
#
#  block6g_expand_conv (Conv2  (None, 1, 1, 1152)           221184    ['block6f_add[0][0]']
#  D)
#
#  block6g_expand_bn (BatchNo  (None, 1, 1, 1152)           4608      ['block6g_expand_conv[0][0]']
#  rmalization)
#
#  block6g_expand_activation   (None, 1, 1, 1152)           0         ['block6g_expand_bn[0][0]']
#  (Activation)
#
#  block6g_dwconv2 (Depthwise  (None, 1, 1, 1152)           10368     ['block6g_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6g_bn (BatchNormaliza  (None, 1, 1, 1152)           4608      ['block6g_dwconv2[0][0]']
#  tion)
#
#  block6g_activation (Activa  (None, 1, 1, 1152)           0         ['block6g_bn[0][0]']
#  tion)
#
#  block6g_se_squeeze (Global  (None, 1152)                 0         ['block6g_activation[0][0]']
#  AveragePooling2D)
#
#  block6g_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6g_se_squeeze[0][0]']
#  e)
#
#  block6g_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multipl  (None, 1, 1, 1152)           0         ['block6g_activation[0][0]',
#  y)                                                                  'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv  (None, 1, 1, 192)            221184    ['block6g_se_excite[0][0]']
#  2D)
#
#  block6g_project_bn (BatchN  (None, 1, 1, 192)            768       ['block6g_project_conv[0][0]']
#  ormalization)
#
#  block6g_drop (Dropout)      (None, 1, 1, 192)            0         ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)           (None, 1, 1, 192)            0         ['block6g_drop[0][0]',
#                                                                      'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2  (None, 1, 1, 1152)           221184    ['block6g_add[0][0]']
#  D)
#
#  block6h_expand_bn (BatchNo  (None, 1, 1, 1152)           4608      ['block6h_expand_conv[0][0]']
#  rmalization)
#
#  block6h_expand_activation   (None, 1, 1, 1152)           0         ['block6h_expand_bn[0][0]']
#  (Activation)
#
#  block6h_dwconv2 (Depthwise  (None, 1, 1, 1152)           10368     ['block6h_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6h_bn (BatchNormaliza  (None, 1, 1, 1152)           4608      ['block6h_dwconv2[0][0]']
#  tion)
#
#  block6h_activation (Activa  (None, 1, 1, 1152)           0         ['block6h_bn[0][0]']
#  tion)
#
#  block6h_se_squeeze (Global  (None, 1152)                 0         ['block6h_activation[0][0]']
#  AveragePooling2D)
#
#  block6h_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6h_se_squeeze[0][0]']
#  e)
#
#  block6h_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multipl  (None, 1, 1, 1152)           0         ['block6h_activation[0][0]',
#  y)                                                                  'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv  (None, 1, 1, 192)            221184    ['block6h_se_excite[0][0]']
#  2D)
#
#  block6h_project_bn (BatchN  (None, 1, 1, 192)            768       ['block6h_project_conv[0][0]']
#  ormalization)
#
#  block6h_drop (Dropout)      (None, 1, 1, 192)            0         ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)           (None, 1, 1, 192)            0         ['block6h_drop[0][0]',
#                                                                      'block6g_add[0][0]']
#
#  top_conv (Conv2D)           (None, 1, 1, 1280)           245760    ['block6h_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 1, 1, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 1, 1, 1280)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d_1  (None, 1280)                 0         ['top_activation[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 1280)                 0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_5 (Dense)             (None, 1024)                 1311744   ['flatten_1[0][0]']
#
#  dense_6 (Dense)             (None, 1024)                 1049600   ['dense_5[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024)                 0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 1024)                 1049600   ['dropout_1[0][0]']
#
#  dense_8 (Dense)             (None, 1024)                 1049600   ['dense_7[0][0]']
#
#  dense_9 (Dense)             (None, 100)                  102500    ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 10482356 (39.99 MB)
# Trainable params: 4563044 (17.41 MB)
# Non-trainable params: 5919312 (22.58 MB)
# __________________________________________________________________________________________________

# %%
last_conv_layer_name = "block2b_expand_conv"#"block2a_expand_conv"#"top_conv"

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data(label_mode='fine')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step

# %%
# Preprocess the data
# x_train = keras.applications.vgg16.preprocess_input(x_train)
# x_test = keras.applications.vgg16.preprocess_input(x_test)
x_train = preprocess_input(x_train)
x_test = preprocess_input(x_test)
# Normalize pixel values to be between 0 and 1
# x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=30, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 35s 15ms/step - loss: 3.6663 - accuracy: 0.1372 - val_loss: 3.0234 - val_accuracy: 0.2441
# Epoch 2/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 2.9887 - accuracy: 0.2494 - val_loss: 2.7735 - val_accuracy: 0.2955
# Epoch 3/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.8033 - accuracy: 0.2861 - val_loss: 2.6621 - val_accuracy: 0.3165
# Epoch 4/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.6846 - accuracy: 0.3126 - val_loss: 2.6030 - val_accuracy: 0.3344
# Epoch 5/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 2.5883 - accuracy: 0.3321 - val_loss: 2.5316 - val_accuracy: 0.3496
# Epoch 6/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 2.5100 - accuracy: 0.3475 - val_loss: 2.5055 - val_accuracy: 0.3534
# Epoch 7/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 2.4385 - accuracy: 0.3631 - val_loss: 2.4774 - val_accuracy: 0.3608
# Epoch 8/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 2.3662 - accuracy: 0.3763 - val_loss: 2.4514 - val_accuracy: 0.3719
# Epoch 9/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 2.3007 - accuracy: 0.3919 - val_loss: 2.4295 - val_accuracy: 0.3770
# Epoch 10/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 2.2536 - accuracy: 0.4032 - val_loss: 2.4171 - val_accuracy: 0.3788
# Epoch 11/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 2.1901 - accuracy: 0.4158 - val_loss: 2.4266 - val_accuracy: 0.3767
# Epoch 12/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 2.1276 - accuracy: 0.4288 - val_loss: 2.4011 - val_accuracy: 0.3784
# Epoch 13/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 2.0712 - accuracy: 0.4419 - val_loss: 2.4090 - val_accuracy: 0.3817
# Epoch 14/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 2.0266 - accuracy: 0.4504 - val_loss: 2.4190 - val_accuracy: 0.3905
# Epoch 15/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 1.9710 - accuracy: 0.4659 - val_loss: 2.4017 - val_accuracy: 0.3920
# Epoch 16/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.9241 - accuracy: 0.4745 - val_loss: 2.3581 - val_accuracy: 0.3989
# Epoch 17/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.8805 - accuracy: 0.4867 - val_loss: 2.3991 - val_accuracy: 0.3972
# Epoch 18/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 1.8266 - accuracy: 0.4970 - val_loss: 2.4122 - val_accuracy: 0.3987
# Epoch 19/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.7859 - accuracy: 0.5077 - val_loss: 2.4522 - val_accuracy: 0.3924
# Epoch 20/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.7303 - accuracy: 0.5200 - val_loss: 2.4244 - val_accuracy: 0.3975
# Epoch 21/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 1.6827 - accuracy: 0.5347 - val_loss: 2.4507 - val_accuracy: 0.4011
# Epoch 22/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.6506 - accuracy: 0.5390 - val_loss: 2.4387 - val_accuracy: 0.3983
# Epoch 23/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.6062 - accuracy: 0.5481 - val_loss: 2.4669 - val_accuracy: 0.4041
# Epoch 24/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.5662 - accuracy: 0.5593 - val_loss: 2.5046 - val_accuracy: 0.3994
# Epoch 25/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.5280 - accuracy: 0.5699 - val_loss: 2.4572 - val_accuracy: 0.3988
# Epoch 26/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 1.4834 - accuracy: 0.5797 - val_loss: 2.5945 - val_accuracy: 0.3965
# Epoch 27/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.4534 - accuracy: 0.5880 - val_loss: 2.4877 - val_accuracy: 0.4057
# Epoch 28/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 1.4132 - accuracy: 0.5999 - val_loss: 2.5204 - val_accuracy: 0.4018
# Epoch 29/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 1.3659 - accuracy: 0.6117 - val_loss: 2.5836 - val_accuracy: 0.4039
# Epoch 30/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 1.3389 - accuracy: 0.6195 - val_loss: 2.5492 - val_accuracy: 0.4030
# Epoch 31/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 1.3185 - accuracy: 0.6214 - val_loss: 2.6061 - val_accuracy: 0.4004
# Epoch 32/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.2832 - accuracy: 0.6326 - val_loss: 2.6406 - val_accuracy: 0.4027
# Epoch 33/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 1.2463 - accuracy: 0.6434 - val_loss: 2.6890 - val_accuracy: 0.3998
# Epoch 34/50
#  241/1563 [===>..........................] - ETA: 18s - loss: 1.1969 - accuracy: 0.6635
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-d0e27c0386cb> in <cell line: 2>()
#       1 # Train the model
# ----> 2 history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# model.save('/content/drive/MyDrive/ARC_101_Prompt_Engineering_Intro/Cifar_simple_04.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Loads the weights
model.load_weights('/content/drive/MyDrive/ARC_101_Prompt_Engineering_Intro/Cifar_simple_04.h5')

# %%
# Evaluate the model on new data
loss, accuracy = model.evaluate(x_test, y_test)

# Print the evaluation results
print('Loss:', loss)
print('Accuracy:', accuracy)
# Out:
# 313/313 [==============================] - 24s 65ms/step - loss: 2.6681 - accuracy: 0.4033
# Loss: 2.6680850982666016
# Accuracy: 0.4032999873161316

# %%
# Get the list of classes
cifar100_classes = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'computer_keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar',
    'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

# %%
# Create a custom decoding function with your custom classes
def custom_decode_predictions(preds, top=5, custom_classes=None):
    if custom_classes is None:
        raise ValueError("Please provide a list of custom classes.")

    # Get the indices of the top predictions
    top_indices = tf.argsort(preds, direction='DESCENDING')[:, :top]

    # Decode the predictions using custom classes
    decoded_predictions = []
    for i in range(top_indices.shape[0]):
        top_classes = [custom_classes[idx] for idx in top_indices[i]]
        decoded_predictions.append(top_classes)

    return decoded_predictions

# Replace YOUR_CUSTOM_CLASSES with your list of 100 class labels
# For example, YOUR_CUSTOM_CLASSES = ['class1', 'class2', ..., 'class100']
# YOUR_CUSTOM_CLASSES = ['class1', 'class2', ..., 'class100']

# %%
# Decode predictions with your custom 100 classes
# custom_decode_predictions = lambda preds: decode_predictions(preds, top=1, custom_classes=cifar100_classes)

# %%
# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", custom_decode_predictions(preds, top=1, custom_classes=cifar100_classes))

# Generate class activation heatmap
heatmap = generate_heatmap_efficientnet_v2(img_array, model, last_conv_layer_name)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Predicted: [['camel']]

# %%
heatmap.shape
# Out:
# (8, 8)

# %% [markdown]
# # In the context of class activation maps or gradient-based visualizations, the color intensity in the generated heatmap typically represents the importance or activation level of different regions in the input image. In most visualizations, warmer colors (e.g., red or yellow) indicate higher activations, while cooler colors (e.g., blue) indicate lower activations.

# %%
# Remove last layer's softmax
# model.layers[-1].activation = None
# Display heatmap
plt.matshow(heatmap,fignum=None)
plt.show()

# %% [markdown]
# ## Create a superimposed visualization

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.utils.load_img(img_path)
    img = keras.utils.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = mpl.colormaps["jet"]

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.utils.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.utils.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.utils.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))


save_and_display_gradcam("/content/Best-Horses-Quarter-Horse.jpg", heatmap)
